# %%
# Imports
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ### General Description of "Zaanstad boorpunten data":
# - Name: Zaanstad boorpunten data
# - Type: Categorical variable
#
# ### Categories:
# - Below AW (Above Water)
# - Above AW
# - Above I (Indicator)
#
# Description: This variable represents soil measurements categorized into three groups based on their relative position to water levels. <br>
# Size: The dataset contains a certain number of observations corresponding to different soil measurements. <br>
#
# ### Transformations:
# Filtering by Measurement Year: Remove all rows that are measured before 2008. <br>
# Spatial Filtering: Include only points that have 10 neighboring points within a radius of 25 meters. Points with more than 10 neighboring points should also be included.

# %%
# Load the specific layer from the geopackage
gdf = gpd.read_file("../Data/Bodemloket_20231009_Antea_Group.gpkg", layer="TBL_WFS_GEO_BORING_ONDERZOEK")

# %%
# Describtion of the raw data
print("General Description of Zaanstad boorpunten data:")
print("Number of observations:", len(gdf))
print("Categories and their counts:")
print(zaanstad_data_filtered['TOETS_WBB'].value_counts())
# Out:
# General Description of Zaanstad boorpunten data:
# Number of observations: 50537
# Categories and their counts:
# >I      7155
# >AW     6631
# <=AW    2402
# >T      2337
# Name: TOETS_WBB, dtype: int64

# %%
# Transformation 1: Removing NULL values from DATUM_RAP and TOETS_WBB columns
gdf = gdf.dropna(subset=['DATUM_RAP'])
gdf = gdf.dropna(subset=['TOETS_WBB'])

# %%
# Transformation 2: Filtering by Measurement Year
# Convert DATUM_RAP to datetime format
gdf['DATUM_RAP'] = pd.to_datetime(gdf['DATUM_RAP'], format='%d-%m-%Y')

# Remove all measurements before 2008
gdf = gdf[gdf['DATUM_RAP'].dt.year >= 2008]

# %%
# Transformation 3: Spatial Filtering
# Calculate number of neighboring points within a radius of 25 meters
gdf['neighbors'] = gdf.geometry.apply(lambda x: len(gdf[gdf.geometry.within(x.buffer(25))]) - 1) # Subtract 1 to exclude the point itself

# %%
# Filter points with 10 or more neighbors
zaanstad_data_filtered = gdf[gdf['neighbors'] >= 10]

# %%
zaanstad_data_filtered
# Out:
#               ID  BOORPUNT_ID NAAM_BOORPUNT BOORPUNTTYPE EINDDIEPTE  DIEPTEGW  \
# 23      492172.0     492172.0            69  grondboring      50 cm  \n
# 24      492173.0     492173.0            70  grondboring      50 cm  \n
# 29      492178.0     492178.0            75  grondboring      50 cm  \n
# 31      492180.0     492180.0            77  grondboring      50 cm  \n
# 108     492181.0     492181.0            78  grondboring      50 cm  \n
# ...          ...          ...           ...          ...        ...       ...
# 119951  493044.0     493044.0           027  grondboring      60 cm  \n
# 119952  493048.0     493048.0           031  grondboring      50 cm  \n
# 119953  493064.0     493064.0           201  grondboring     150 cm  \n
# 119954  493068.0     493068.0           102  grondboring     150 cm  \n
# 119957  493080.0     493080.0          1001     peilbuis     320 cm    150 cm
#
#        TOETS_WBB TOETS_GW          TOETS_BBK OPMERKINGEN  ONDERZOEK_ID  \
# 23          <=AW     None  Achtergrondwaarde        None      520436.0
# 24          <=AW     None  Achtergrondwaarde        None      520436.0
# 29          <=AW     None  Achtergrondwaarde        None      520436.0
# 31          <=AW     None  Achtergrondwaarde        None      520436.0
# 108         <=AW     None  Achtergrondwaarde        None      520436.0
# ...          ...      ...                ...         ...           ...
# 119951        >I     None    Niet toepasbaar        None      520878.0
# 119952        >I     None    Niet toepasbaar        None      520878.0
# 119953       >AW     None              Wonen        None      520878.0
# 119954       >AW     None              Wonen        None      520878.0
# 119957        >T       >S          Industrie        None      520878.0
#
#        ONDERZOEKCODE                    TYPE_OND  \
# 23       NZ047902424  Orienterend bodemonderzoek
# 24       NZ047902424  Orienterend bodemonderzoek
# 29       NZ047902424  Orienterend bodemonderzoek
# 31       NZ047902424  Orienterend bodemonderzoek
# 108      NZ047902424  Orienterend bodemonderzoek
# ...              ...                         ...
# 119951   NZ047902475    Nader en Asbestonderzoek
# 119952   NZ047902475    Nader en Asbestonderzoek
# 119953   NZ047902475    Nader en Asbestonderzoek
# 119954   NZ047902475    Nader en Asbestonderzoek
# 119957   NZ047902475    Nader en Asbestonderzoek
#
#                                                  NAAM_RAP  \
# 23      UNDER CONSTRUCTION - Loodlocatie L233 - Oriënt...
# 24      UNDER CONSTRUCTION - Loodlocatie L233 - Oriënt...
# 29      UNDER CONSTRUCTION - Loodlocatie L233 - Oriënt...
# 31      UNDER CONSTRUCTION - Loodlocatie L233 - Oriënt...
# 108     UNDER CONSTRUCTION - Loodlocatie L233 - Oriënt...
# ...                                                   ...
# 119951                   Aris van broekweg 1-3 te Zaandam
# 119952                   Aris van broekweg 1-3 te Zaandam
# 119953                   Aris van broekweg 1-3 te Zaandam
# 119954                   Aris van broekweg 1-3 te Zaandam
# 119957                   Aris van broekweg 1-3 te Zaandam
#
#                         NUMMER_RAP   AUTEUR_RAP  DATUM_RAP LOCATIECODES  \
# 23      R001-1282282TMA-V02-aao-NL      TAUW bv 2021-11-15  ZA047918906
# 24      R001-1282282TMA-V02-aao-NL      TAUW bv 2021-11-15  ZA047918906
# 29      R001-1282282TMA-V02-aao-NL      TAUW bv 2021-11-15  ZA047918906
# 31      R001-1282282TMA-V02-aao-NL      TAUW bv 2021-11-15  ZA047918906
# 108     R001-1282282TMA-V02-aao-NL      TAUW bv 2021-11-15  ZA047918906
# ...                            ...          ...        ...          ...
# 119951                 0458913.138  Antea Group 2020-09-21  NH047900215
# 119952                 0458913.138  Antea Group 2020-09-21  NH047900215
# 119953                 0458913.138  Antea Group 2020-09-21  NH047900215
# 119954                 0458913.138  Antea Group 2020-09-21  NH047900215
# 119957                 0458913.138  Antea Group 2020-09-21  NH047900215
#
#                              geometry  neighbors
# 23      POINT (111844.548 501301.354)         12
# 24      POINT (111833.966 501287.223)         10
# 29      POINT (111899.932 501268.941)         11
# 31      POINT (111828.672 501312.238)         13
# 108     POINT (111825.046 501315.857)         11
# ...                               ...        ...
# 119951  POINT (116058.292 494235.399)         47
# 119952  POINT (116054.797 494255.188)         32
# 119953  POINT (116049.205 494248.979)         41
# 119954  POINT (116027.482 494239.359)         27
# 119957  POINT (116063.292 494245.841)         40
#
# [18525 rows x 20 columns]
